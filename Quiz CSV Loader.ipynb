# %% [markdown]
# # Quiz CSV Loader
#
# This notebook is used to download CSVs from Google Cloud Storage, perform some processing, and insert the data into a MySQL database.
#
# The format of the CSV is expected to look like this:
#
# ```
# ,Question,Answer,Correct
# ,Which regression model uses the L1 regularization technique?,Ridge Regression,FALSE
# ,,Lasso Regression,TRUE
# ,,Both A and B,FALSE
# ,,None of the above,FALSE
# ,What would you use to solve the problem of overfitting?,Regularization technique,FALSE
# ,,Cross Validation,FALSE
# ,,Drop out,FALSE
# ,,All of the above,TRUE
# ```
#
# Note that the first column is empty in all cases. If the second column (the `Question` column) is empty, it's implied that the row contains an answer pertaining to the last non-empty `Question` value.

# %%
# Install dependencies
# !pip install install cloud-sql-python-connector[pymysql] sqlalchemy
# Out:
# Requirement already satisfied: install in /opt/conda/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied: cloud-sql-python-connector[pymysql] in /opt/conda/lib/python3.7/site-packages (0.5.0)
# Requirement already satisfied: sqlalchemy in /opt/conda/lib/python3.7/site-packages (1.4.28)
# Requirement already satisfied: google-api-python-client in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (2.33.0)
# Requirement already satisfied: pyopenssl in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (21.0.0)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (3.8.1)
# Requirement already satisfied: Requests in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (2.26.0)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (36.0.1)
# Requirement already satisfied: PyMySQL==1.0.2 in /opt/conda/lib/python3.7/site-packages (from cloud-sql-python-connector[pymysql]) (1.0.2)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.7/site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (4.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (21.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (1.7.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (5.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (4.0.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (1.2.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (1.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (0.13.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/conda/lib/python3.7/site-packages (from aiohttp->cloud-sql-python-connector[pymysql]) (2.0.9)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.7/site-packages (from cryptography->cloud-sql-python-connector[pymysql]) (1.15.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=1.21.0 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client->cloud-sql-python-connector[pymysql]) (2.3.2)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client->cloud-sql-python-connector[pymysql]) (2.3.3)
# Requirement already satisfied: uritemplate<5,>=3.0.0 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client->cloud-sql-python-connector[pymysql]) (4.1.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client->cloud-sql-python-connector[pymysql]) (0.20.2)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from google-api-python-client->cloud-sql-python-connector[pymysql]) (0.1.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->sqlalchemy) (3.6.0)
# Requirement already satisfied: six>=1.5.2 in /opt/conda/lib/python3.7/site-packages (from pyopenssl->cloud-sql-python-connector[pymysql]) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.7/site-packages (from Requests->cloud-sql-python-connector[pymysql]) (3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from Requests->cloud-sql-python-connector[pymysql]) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from Requests->cloud-sql-python-connector[pymysql]) (1.26.7)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.12->cryptography->cloud-sql-python-connector[pymysql]) (2.21)
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (3.19.1)
# Requirement already satisfied: setuptools>=40.3.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (59.6.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /opt/conda/lib/python3.7/site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (1.53.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (0.2.7)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (4.8)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/conda/lib/python3.7/site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (3.0.6)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client->cloud-sql-python-connector[pymysql]) (0.4.8)

# %%
# First, load the CSV locally.
# !mkdir -p csvs
# !gsutil cp gs://ml-quiz-project-csvs/* csvs/.
# Out:
# Copying gs://ml-quiz-project-csvs/art-and-science-of-ml.csv...
# / [1 files][ 17.5 KiB/ 17.5 KiB]
# Operation completed over 1 objects/17.5 KiB.

# %%
# Import ribraries
from google.cloud.sql.connector import connector
import pandas as pd
import uuid
import pymysql
import sqlalchemy

# %%
df = pd.read_csv("csvs/art-and-science-of-ml.csv")
df = df[["Question", "Answer", "Correct"]]
df = df[~df.Answer.isnull()]
df.Question.ffill(inplace=True)
# df['question_id'] = df['Question'].apply(lambda x: x.ffill().shift(1))
df
# Out:
#                                               Question  \
# 0    Which regression model uses the L1 regularizat...
# 1    Which regression model uses the L1 regularizat...
# 2    Which regression model uses the L1 regularizat...
# 3    Which regression model uses the L1 regularizat...
# 4    What would you use to solve the problem of ove...
# ..                                                 ...
# 145  Which of the following statements is true abou...
# 146     Which of the following statement is incorrect?
# 147     Which of the following statement is incorrect?
# 148     Which of the following statement is incorrect?
# 149     Which of the following statement is incorrect?
#
#                                                 Answer  Correct
# 0                                     Ridge Regression    False
# 1                                     Lasso Regression     True
# 2                                         Both A and B    False
# 3                                    None of the above    False
# 4                             Regularization technique    False
# ..                                                 ...      ...
# 145  For a logit layer, similar to a single logit, ...    False
# 146  The Categorical columns are represented by ten...    False
# 147  Tensorflow can do math operations on sparse te...    False
# 148  The more dimensions you have, the greater chan...    False
# 149                                  None of the above     True
#
# [150 rows x 3 columns]

# %%
unique_questions = pd.Series(df.Question.unique())
questions = pd.DataFrame({"question_id": unique_questions.apply(lambda x: uuid.uuid4()), "question": unique_questions})
joined_table = pd.merge(questions, df, left_on='question', right_on='Question')
joined_table['answer_id'] = [uuid.uuid4() for _ in range(len(df.index))]
answers = joined_table[['question_id', 'answer_id', 'Answer', 'Correct']]
answers = answers.rename({'Answer': 'answer', 'Correct': 'correct'}, axis='columns')
questions
# Out:
#                              question_id  \
# 0   893c4e4e-ff2c-44e4-8ca7-a00eefbfb04b
# 1   cdb1de42-d551-4767-822c-76af25d4b4d3
# 2   da1194e5-230a-4c04-ae00-7437363e114b
# 3   d6c807a2-e848-4fc9-a713-7a3734058a49
# 4   1194e2f3-72d6-4a83-af82-48f1d0dad1b9
# 5   081ed117-46d5-4326-9f69-4f409dc9d877
# 6   766f15f0-a899-4e93-a256-f2acfaee97ba
# 7   0ada3e1c-aea9-404a-8839-ec2f9a7144ed
# 8   e10d8aca-8911-4abd-b13d-e8eb6f930f00
# 9   578e1df9-5eb9-4aaf-baf5-aa199d55f7ce
# 10  12c64c3b-7432-47be-a849-9c29ead3dbf7
# 11  5f511bd2-2e37-4b91-a6ed-063f4ec889e3
# 12  de0cae3d-0a96-4fc6-b741-c5788a625764
# 13  a5e101ce-5bae-4711-9d31-09b84814c85f
# 14  2fe84f68-331b-489e-8f2f-cdf4f9352d21
# 15  605aea1e-ac2f-49ae-8c69-03f6bda68a92
# 16  f7f06773-26e9-47e3-b6f0-1d2a267fbdce
# 17  3d3311b1-f015-41be-be5e-034cbf34428f
# 18  58b087d9-e0ec-4353-a98d-50dc73f8e6b6
# 19  10911343-c347-440c-85ba-a7b35702fff8
# 20  06f32ad9-58ac-4998-b96c-8fbff3d767b5
# 21  62d8055f-38f5-4a95-8f32-d92758014660
# 22  6bd41e37-6806-4ee7-9623-ab5746d18c51
# 23  e697ef48-042c-4b9c-b610-969214051100
# 24  96ad6715-d2bb-4c51-b4d6-8cc183275e93
# 25  a49b4e87-207b-4fd7-9131-2917860a8cd3
# 26  73413219-bf43-4c41-aa77-552dcadbbd71
# 27  6b2e3dd5-1494-4c0d-8127-5fb7e512b13c
# 28  953d0466-97a1-45ea-a1e6-ecbc34b2b47d
# 29  fab1ec05-4c43-4a47-b0ed-a0dbb4c42f19
# 30  52793508-d61c-4a10-be64-a8b94678c8e7
# 31  dd5ddcb5-7d75-4912-82d8-4a0844b7bf42
# 32  4afbe8f3-e374-4f34-ba67-ee031eef0852
# 33  bbd73914-a9de-4f7a-91c3-c17bd5021dc4
# 34  10f6d2e4-e33a-4bb6-bb49-ba940bf8f4c0
# 35  d533b73b-ae1f-4200-be22-2d99c84cb58b
# 36  583a5ea4-3665-41ed-b8dd-8d9743532515
# 37  924feb21-711b-497d-a5dc-73183e2a7a0a
#
#                                              question
# 0   Which regression model uses the L1 regularizat...
# 1   What would you use to solve the problem of ove...
# 2        Why would you use the square of the L2 norm?
# 3   Which regression model uses the L2 regularizat...
# 4                       Why is regularization useful?
# 5   Which of the following is not true about the L...
# 6   Which of the following is an example of a hype...
# 7   How would you use the Cloud AI Platform Traini...
# 8   How would you ensure the outputs of different ...
# 9   How do you supply hyperparameters to the train...
# 10  Model improvement depends on which of the foll...
# 11  To improve the model, which of the following i...
# 12  A hyper-parameter is a setting you set before ...
# 13                         What is L2 Regularization?
# 14                         What is L1 regularization?
# 15             What are the benefits of sparse model?
# 16  What are the differences between L1 regulariza...
# 17  Why is it recommended that a high-dimensional ...
# 18  What are the constraints used in the sigmoid a...
# 19       What does the output of a sigmoid represent?
# 20                 A cross-entropy of zero indicates:
# 21  Why is regularization important in logistic re...
# 22  Why is it important for the gradient not to be...
# 23  Which of the following statements are correct ...
# 24  Which of the following gives non-linearity to ...
# 25  During the training process for deep networks,...
# 26  How can you solve the problem where gradients ...
# 27  In a neural network, which of the following te...
# 28  Which of the following trainer modes should yo...
# 29  Which of the following normalization methods s...
# 30               What is a Multiclass Neural Network?
# 31  Which tensorFlow function can you use to calcu...
# 32  Which function you use If labels aren't mutual...
# 33  Which of the following is an efficient way to ...
# 34  Which of the following is a disadvantage of de...
# 35    Which of the following is true about embedding?
# 36  Which of the following statements is true abou...
# 37     Which of the following statement is incorrect?

# %%
questions.head(n=10)
# Out:
#                             question_id  \
# 0  7a11d277-4a54-44c0-af3e-203c1e1b7103
# 1  2647ca03-14ac-47c3-ae02-8d1337f5c7af
# 2  883f5170-e629-46ca-8ffe-e0c36c9f6645
# 3  13d058ca-eaf5-4ef3-a7ad-aa0b3469b42c
# 4  50808aa4-d80f-4868-a700-38044e5bc956
# 5  edde16af-6587-4c1a-98b1-0e5ebd3ee555
# 6  77eff38f-f4c9-4b86-ab3e-e754132e1004
# 7  b0ba7d34-aa07-42a5-ab71-0b191cb02f1b
# 8  bb0ea1fe-44e6-4960-8c1f-f3b93fac4e80
# 9  c996a3b4-ef33-4f11-a119-03664d6a75be
#
#                                             question
# 0  Which regression model uses the L1 regularizat...
# 1  What would you use to solve the problem of ove...
# 2       Why would you use the square of the L2 norm?
# 3  Which regression model uses the L2 regularizat...
# 4                      Why is regularization useful?
# 5  Which of the following is not true about the L...
# 6  Which of the following is an example of a hype...
# 7  How would you use the Cloud AI Platform Traini...
# 8  How would you ensure the outputs of different ...
# 9  How do you supply hyperparameters to the train...

# %%
answers.head(n=10)
# Out:
#                             question_id                             answer_id  \
# 0  7a11d277-4a54-44c0-af3e-203c1e1b7103  3d76e3ea-ed64-4756-92f6-14c555659dc0
# 1  7a11d277-4a54-44c0-af3e-203c1e1b7103  ab4cb843-938c-4cac-95a0-7624d7f43f80
# 2  7a11d277-4a54-44c0-af3e-203c1e1b7103  b7f161e6-9963-4fa0-bdb6-771149f91ec4
# 3  7a11d277-4a54-44c0-af3e-203c1e1b7103  33e8f168-d9a6-4842-bcf7-2cec2bbef8ff
# 4  2647ca03-14ac-47c3-ae02-8d1337f5c7af  14331346-70fa-4cd8-b88e-100695dd48d8
# 5  2647ca03-14ac-47c3-ae02-8d1337f5c7af  00a55669-eb9f-4ec7-a324-f43fa2242a62
# 6  2647ca03-14ac-47c3-ae02-8d1337f5c7af  079bf31c-be7d-4eda-a5e1-9e64577fdc45
# 7  2647ca03-14ac-47c3-ae02-8d1337f5c7af  28822016-2ab9-40ed-93c1-7b977c464f7a
# 8  883f5170-e629-46ca-8ffe-e0c36c9f6645  c0177bfd-0e28-43a4-a2f5-3ddf1fa096fa
# 9  883f5170-e629-46ca-8ffe-e0c36c9f6645  47172bfb-cc1f-4ab0-89c8-082b55315422
#
#                                        answer  correct
# 0                            Ridge Regression    False
# 1                            Lasso Regression     True
# 2                                Both A and B    False
# 3                           None of the above    False
# 4                    Regularization technique    False
# 5                            Cross Validation    False
# 6                                    Drop out    False
# 7                            All of the above     True
# 8  To increase the calculation of derivatives    False
# 9              To minimize the training error    False

# %%
answers.dtypes
# Out:
# question_id    object
# answer_id      object
# answer         object
# correct          bool
# dtype: object

# %% [markdown]
# # Setup Database
# Here, we will establish a connection to the database, create or replace the required tables, and load the data in from the above Dataframes.

# %%
def getconn() -> pymysql.connections.Connection:
    conn: pymysql.connections.Connection = connector.connect(
        "ml-quiz-project:us-central1:quiz-data",
        "pymysql",
        user="root",
        password=None,
        db="quiz_data"
    )
    return conn

pool = sqlalchemy.create_engine(
    "mysql+pymysql://",
    creator=getconn,
)

'''

DROP TABLE IF EXISTS `answers`;
    CREATE TABLE `answers` (
        answer_id VARCHAR(256) NOT NULL PRIMARY KEY,
        question_id VARCHAR(256) NOT NULL,
        answer TEXT NOT NULL,
        correct tinyint(1) NOT NULL
    );
    '''

'''
db_conn.execute("""
    DROP TABLE IF EXISTS `answers`;
    
    """)
    db_conn.execute("""
    CREATE TABLE `questions` (
        question_id VARCHAR(256) NOT NULL PRIMARY KEY,
        question TEXT NOT NULL
    );
    """)
    db_conn.execute("""
    DROP TABLE IF EXISTS `questions`;
    """)
    db_conn.execute("""
     CREATE TABLE `answers` (
        answer_id VARCHAR(256) NOT NULL PRIMARY KEY,
        question_id VARCHAR(256) NOT NULL,
        answer TEXT NOT NULL,
        correct tinyint(1) NOT NULL,
        FOREIGN KEY (question_id) REFERENCES questions(question_id)
    );
    """)
    '''



with pool.connect() as db_conn:
    # query database
    
    
    questions.to_sql('questions', if_exists='replace', flavor='mysql')
    answers.to_sql('answers', if_exists='replace', flavor='mysql')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# /opt/conda/lib/python3.7/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# /opt/conda/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (1217, 'Cannot delete or update a parent row: a foreign key constraint fails')
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /tmp/ipykernel_2618/1716638311.py in <module>
#      31     db_conn.execute("""
#      32     DROP TABLE IF EXISTS `questions`;
# ---> 33     """)
#      34     db_conn.execute("""
#      35     CREATE TABLE `questions` (
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1277                 params,
#    1278                 _EMPTY_EXECUTION_OPTS,
# -> 1279                 future=False,
#    1280             )
#    1281
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1583             execution_options,
#    1584             statement,
# -> 1585             distilled_parameters,
#    1586         )
#    1587
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
#    1802                     self.dialect.do_execute(
# -> 1803                         cursor, statement, parameters, context
#    1804                     )
#    1805
#
# /opt/conda/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     730
#     731     def do_execute(self, cursor, statement, parameters, context=None):
# --> 732         cursor.execute(statement, parameters)
#     733
#     734     def do_execute_no_params(self, cursor, statement, context=None):
#
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# /opt/conda/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# /opt/conda/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# /opt/conda/lib/python3.7/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# /opt/conda/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1217, 'Cannot delete or update a parent row: a foreign key constraint fails')
# [SQL:
#     DROP TABLE IF EXISTS `questions`;
#     ]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
